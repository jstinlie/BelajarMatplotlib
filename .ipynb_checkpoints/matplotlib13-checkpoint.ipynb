# %% [markdown]
# # Matplotlib 13 - 3D Plotting

# %% [markdown]
# # Import Modules

# %%
# %matplotlib inline
# %matplotlib notebook # untuk berinteraksi dengan 3d plotting yang dihasilkan

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.3.2
# 1.19.2

# %% [markdown]
# # 3D Axes

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">
